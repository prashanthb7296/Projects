# %% [markdown]
# # **LISTED CAREERS**

# %% [markdown]
# ## **AUTHOR: PRASHANTH B**

# %% [markdown]
# **TASK: IMAGE CAPTION GENERATOR**

# %% [markdown]
# **Step 1: Installing transformers library**

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Step 2: Importing Relevant Libraries**

# %%
import requests
from PIL import Image
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration

# %% [markdown]
# **Step 3: Utilizing a Pre-Trained Model - BlipProcessor from HuggingFace**

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %% [markdown]
# **Step 4: Testing**

# %% [markdown]
# **IMAGE 1**

# %%
img_url = 'https://drive.google.com/uc?id=1mdgPc-axVRRHwCd9OKj-2AUdNKDG_Qir'
response = requests.get(img_url) 
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')
raw_image = Image.open(BytesIO(response.content)).convert('RGB')

# %%
import matplotlib.pyplot as plt

plt.imshow(raw_image)
plt.axis('off')
plt.show()

# %% [markdown]
# **Conditional image captioning**

# %%
text = "a photography of"
inputs = processor(raw_image, text, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a photography of a man playing soccer

# %% [markdown]
# **Unconditional image captioning**

# %%
inputs = processor(raw_image, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a man running on a soccer field

# %% [markdown]
# **IMAGE 2**

# %%
img_url = 'https://drive.google.com/uc?id=1IrkulhGfkLpRHlGUQJWzYjuYUGwpRBU8'
response = requests.get(img_url) 
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')
raw_image = Image.open(BytesIO(response.content)).convert('RGB')

# %%
plt.imshow(raw_image)
plt.axis('off')
plt.show()

# %%
# conditional image captioning
text = "a photography of"
inputs = processor(raw_image, text, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a photography of two horses standing in a field

# %%
# unconditional image captioning
inputs = processor(raw_image, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# two horses standing in a field under a cloudy sky

# %% [markdown]
# **IMAGE 3**

# %%
img_url = 'https://drive.google.com/uc?id=1EcHWrL5uwYDtAKqGJTl0-rf4Ghxrj8jU'
response = requests.get(img_url) 
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')
raw_image = Image.open(BytesIO(response.content)).convert('RGB')

# %%
plt.imshow(raw_image)
plt.axis('off')
plt.show()

# %%
# conditional image captioning
text = "a photography of"
inputs = processor(raw_image, text, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a photography of a group of people with the words'oraly adpers '

# %%
# unconditional image captioning
inputs = processor(raw_image, return_tensors="pt")
out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# a poster with the names of the different actors

# %% [markdown]
# # **THANK YOU**
